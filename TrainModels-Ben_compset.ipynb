# %% [markdown]
# # Train the various models

# %%
# import libraries
import os
import pandas as pd
from tensor2tensor.utils import registry
from tensor2tensor.data_generators import text_problems #, token_generator, EOS
from tensor2tensor.data_generators import problem
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0727 05:37:19.482200 140338489177920 lazy_loader.py:50]
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# W0727 05:37:20.539190 140338489177920 deprecation_wrapper.py:119] From /home/arnoldyb/anaconda3/lib/python3.7/site-packages/tensor2tensor/utils/expert_utils.py:68: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.

# %% [markdown]
# ### BEN: RUN THIS SERIES -- THIS IS TRAINING DATA, FILTERED BY SENTIMENT
# Make sure Gavrilov.py points to meta_train.log

# %%
! t2t-trainer \
--t2t_usr_dir="." \
--generate_data \
--problem="gavrilov" \
--model="universal_transformer" \
--hparams_set="universal_transformer_gavrilov" \
--data_dir="./t2t_data_comp/" \
--output_dir="./t2t_data_comp/model" \
--train_steps=1000 \
--eval_steps=1000
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0727 05:37:23.163030 139984199841600 deprecation_wrapper.py:119] From /home/arnoldyb/anaconda3/lib/python3.7/site-packages/tensor2tensor/utils/expert_utils.py:68: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# W0727 05:37:23.794983 139984199841600 lazy_loader.py:50]
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# ...

# %%
! t2t-trainer \
--t2t_usr_dir="." \
--generate_data \
--problem="gavrilov" \
--model="universal_transformer" \
--hparams_set="universal_transformer_gavrilov" \
--data_dir="./t2t_data_comp/" \
--output_dir="./t2t_data_comp/model" \
--train_steps=2000 \
--eval_steps=2000
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0727 10:06:38.065896 139936294774592 deprecation_wrapper.py:119] From /home/arnoldyb/anaconda3/lib/python3.7/site-packages/tensor2tensor/utils/expert_utils.py:68: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# W0727 10:06:38.671947 139936294774592 lazy_loader.py:50]
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# ...

# %%
! t2t-trainer \
--t2t_usr_dir="." \
--generate_data \
--problem="gavrilov" \
--model="universal_transformer" \
--hparams_set="universal_transformer_gavrilov" \
--data_dir="./t2t_data_comp/" \
--output_dir="./t2t_data_comp/model" \
--train_steps=3000 \
--eval_steps=3000
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0727 13:22:38.813970 140385799259968 deprecation_wrapper.py:119] From /home/arnoldyb/anaconda3/lib/python3.7/site-packages/tensor2tensor/utils/expert_utils.py:68: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# W0727 13:22:39.415014 140385799259968 lazy_loader.py:50]
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# ...

# %%
! t2t-trainer \
--t2t_usr_dir="." \
--generate_data \
--problem="gavrilov" \
--model="universal_transformer" \
--hparams_set="universal_transformer_gavrilov" \
--data_dir="./t2t_data_comp/" \
--output_dir="./t2t_data_comp/model" \
--train_steps=4000 \
--eval_steps=4000
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0727 16:46:53.613137 140453568112448 deprecation_wrapper.py:119] From /home/arnoldyb/anaconda3/lib/python3.7/site-packages/tensor2tensor/utils/expert_utils.py:68: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# W0727 16:46:54.228593 140453568112448 lazy_loader.py:50]
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# ...

# %%
! t2t-trainer \
--t2t_usr_dir="." \
--generate_data \
--problem="gavrilov" \
--model="universal_transformer" \
--hparams_set="universal_transformer_gavrilov" \
--data_dir="./t2t_data_comp/" \
--output_dir="./t2t_data_comp/model" \
--train_steps=5000 \
--eval_steps=5000

# %%
! t2t-trainer \
--t2t_usr_dir="." \
--generate_data \
--problem="gavrilov" \
--model="universal_transformer" \
--hparams_set="universal_transformer_gavrilov" \
--data_dir="./t2t_data_comp/" \
--output_dir="./t2t_data_comp/model" \
--train_steps=6000 \
--eval_steps=6000

# %%
! t2t-trainer \
--t2t_usr_dir="." \
--generate_data \
--problem="gavrilov" \
--model="universal_transformer" \
--hparams_set="universal_transformer_gavrilov" \
--data_dir="./t2t_data_comp/" \
--output_dir="./t2t_data_comp/model" \
--train_steps=7000 \
--eval_steps=7000

# %%
! t2t-trainer \
--t2t_usr_dir="." \
--generate_data \
--problem="gavrilov" \
--model="universal_transformer" \
--hparams_set="universal_transformer_gavrilov" \
--data_dir="./t2t_data_comp/" \
--output_dir="./t2t_data_comp/model" \
--train_steps=8000 \
--eval_steps=8000

# %%
! t2t-trainer \
--t2t_usr_dir="." \
--generate_data \
--problem="gavrilov" \
--model="universal_transformer" \
--hparams_set="universal_transformer_gavrilov" \
--data_dir="./t2t_data_comp/" \
--output_dir="./t2t_data_comp/model" \
--train_steps=9000 \
--eval_steps=9000

# %%
! t2t-trainer \
--t2t_usr_dir="." \
--generate_data \
--problem="gavrilov" \
--model="universal_transformer" \
--hparams_set="universal_transformer_gavrilov" \
--data_dir="./t2t_data_comp/" \
--output_dir="./t2t_data_comp/model" \
--train_steps=10000 \
--eval_steps=10000
